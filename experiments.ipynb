# %%
from epistemic_space import *

# %%
possibleworlds = PossibleWorlds(3,["I am there","you got it","do it more"],True)

# %%
possibleworlds.possibilities
# Out:
# ['W0', 'W1', 'W2', 'W3', 'W4', 'W5', 'W6', 'W7']

# %%
P(3)
# Out:
# <P3: worlds=['W0', 'W1'], bitstring=00000011>

# %%
P(9)
# Out:
# <P9: worlds=['W0', 'W3'], bitstring=00001001>

# %%
P(22)
# Out:
# <P22: worlds=['W1', 'W2', 'W4'], bitstring=00010110>

# %%
P(5555555555)
# Out:
# <P5555555555 (does not exist): does not exist, max index=255>

# %%
W(3)
# Out:
# <W3: bitstring=011, notation=¬B1 ∩ B2 ∩ B3>
